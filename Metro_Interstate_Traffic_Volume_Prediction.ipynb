# %% [markdown]
# ##Importing data + libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Metro_Interstate_Traffic_Volume.csv',parse_dates=[7])
df
# Out:
#       holiday    temp  ...           date_time  traffic_volume
# 0        None  288.28  ... 2012-10-02 09:00:00            5545
# 1        None  289.36  ... 2012-10-02 10:00:00            4516
# 2        None  289.58  ... 2012-10-02 11:00:00            4767
# 3        None  290.13  ... 2012-10-02 12:00:00            5026
# 4        None  291.14  ... 2012-10-02 13:00:00            4918
# ...       ...     ...  ...                 ...             ...
# 48199    None  283.45  ... 2018-09-30 19:00:00            3543
# 48200    None  282.76  ... 2018-09-30 20:00:00            2781
# 48201    None  282.73  ... 2018-09-30 21:00:00            2159
# 48202    None  282.09  ... 2018-09-30 22:00:00            1450
# 48203    None  282.12  ... 2018-09-30 23:00:00             954
#
# [48204 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48204 entries, 0 to 48203
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   holiday              48204 non-null  object
#  1   temp                 48204 non-null  float64
#  2   rain_1h              48204 non-null  float64
#  3   snow_1h              48204 non-null  float64
#  4   clouds_all           48204 non-null  int64
#  5   weather_main         48204 non-null  object
#  6   weather_description  48204 non-null  object
#  7   date_time            48204 non-null  datetime64[ns]
#  8   traffic_volume       48204 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(2), object(3)
# memory usage: 3.3+ MB

# %%
df.shape
# Out:
# (48204, 9)

# %%
df.isna().sum()
# Out:
# holiday                0
# temp                   0
# rain_1h                0
# snow_1h                0
# clouds_all             0
# weather_main           0
# weather_description    0
# date_time              0
# traffic_volume         0
# dtype: int64

# %%
df.describe()
# Out:
#                temp       rain_1h       snow_1h    clouds_all  traffic_volume
# count  48204.000000  48204.000000  48204.000000  48204.000000    48204.000000
# mean     281.205870      0.334264      0.000222     49.362231     3259.818355
# std       13.338232     44.789133      0.008168     39.015750     1986.860670
# min        0.000000      0.000000      0.000000      0.000000        0.000000
# 25%      272.160000      0.000000      0.000000      1.000000     1193.000000
# 50%      282.450000      0.000000      0.000000     64.000000     3380.000000
# 75%      291.806000      0.000000      0.000000     90.000000     4933.000000
# max      310.070000   9831.300000      0.510000    100.000000     7280.000000

# %%
df['date_time'].min(),df['date_time'].max()
# Out:
# (Timestamp('2012-10-02 09:00:00'), Timestamp('2018-09-30 23:00:00'))

# %%
df.holiday.value_counts()
# Out:
# None                         48143
# Labor Day                        7
# Martin Luther King Jr Day        6
# Thanksgiving Day                 6
# New Years Day                    6
# Christmas Day                    6
# Washingtons Birthday             5
# Memorial Day                     5
# Columbus Day                     5
# State Fair                       5
# Independence Day                 5
# Veterans Day                     5
# Name: holiday, dtype: int64

# %% [markdown]
# ## Very Extensive EDA

# %%
sns.boxplot(x=df["temp"])

# %%
df['temp'].min()
# Out:
# 0.0

# %%
df=df[(df['temp']>df['temp'].min())]
sns.boxplot(data=df,x=df['temp'])

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.hist(df['temp'], color='b')
plt.subplot(1,2,2)
sns.kdeplot(data= df.temp)

# %%
plt.scatter(df['traffic_volume'],df['temp'],c='G',alpha=0.2)
plt.ylabel('Temperature')
plt.xlabel('Traffic Count')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: MatplotlibDeprecationWarning: Support for uppercase single-letter colors is deprecated since Matplotlib 3.1 and will be removed in 3.3; please use lowercase instead.
#   """Entry point for launching an IPython kernel.
# Text(0.5, 0, 'Traffic Count')

# %%
sns.boxplot(data=df,x=df["rain_1h"])

# %%
df["rain_1h"].max()
# Out:
# 9831.3

# %%
df = df[df["rain_1h"]< df["rain_1h"].max()]

# %%
df.shape
# Out:
# (48193, 9)

# %%
df["rain_1h"].value_counts()
# Out:
# 0.00     44727
# 0.25       948
# 0.51       256
# 1.02       123
# 0.30       121
#          ...
# 2.84         1
# 18.03        1
# 2.73         1
# 12.45        1
# 2.11         1
# Name: rain_1h, Length: 371, dtype: int64

# %%
df["rain_1h"].describe()
# Out:
# count    48193.000000
# mean         0.130342
# std          1.003480
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max         55.630000
# Name: rain_1h, dtype: float64

# %%
sns.boxplot(data=df, x=df['rain_1h'])

# %%
df["holiday"].value_counts()
# Out:
# None                         48132
# Labor Day                        7
# Martin Luther King Jr Day        6
# Thanksgiving Day                 6
# New Years Day                    6
# Christmas Day                    6
# Washingtons Birthday             5
# Memorial Day                     5
# Columbus Day                     5
# State Fair                       5
# Independence Day                 5
# Veterans Day                     5
# Name: holiday, dtype: int64

# %%
plt.scatter(df['traffic_volume'],df['rain_1h'],c='M',alpha=0.7)
plt.ylabel('Amount of rain in 1 hour')
plt.xlabel('Traffic Count')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: MatplotlibDeprecationWarning: Support for uppercase single-letter colors is deprecated since Matplotlib 3.1 and will be removed in 3.3; please use lowercase instead.
#   """Entry point for launching an IPython kernel.
# Text(0.5, 0, 'Traffic Count')

# %%
df['snow_1h'].describe()
# Out:
# count    48193.000000
# mean         0.000222
# std          0.008169
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          0.510000
# Name: snow_1h, dtype: float64

# %%
plt.scatter(df['traffic_volume'],df['snow_1h'],c='M',alpha=0.7)
plt.ylabel('Amount of snow in 1 hour')
plt.xlabel('Traffic Count')
# Out:
# Text(0.5, 0, 'Traffic Count')

# %%
df['clouds_all'].describe()
# Out:
# count    48193.000000
# mean        49.371942
# std         39.013548
# min          0.000000
# 25%          1.000000
# 50%         64.000000
# 75%         90.000000
# max        100.000000
# Name: clouds_all, dtype: float64

# %%
df['date_time'].describe()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   """Entry point for launching an IPython kernel.
# count                   48193
# unique                  40564
# top       2013-04-18 22:00:00
# freq                        6
# first     2012-10-02 09:00:00
# last      2018-09-30 23:00:00
# Name: date_time, dtype: object

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.hist(df['clouds_all'], color='b')
plt.subplot(1,2,2)
sns.kdeplot(data= df.clouds_all)

# %%
plt.scatter(df['traffic_volume'],df['clouds_all'],c='M',alpha=0.7)
plt.ylabel('Percentage of cloud coverage')
plt.xlabel('Traffic Count')
# Out:
# Text(0.5, 0, 'Traffic Count')

# %%
plt.figure(figsize = (30,10))
data2 = df[df['weather_main']=='Snow']
sns.boxplot(x= data2['weather_description'], y= data2['snow_1h'], data = data2)

# %%
plt.figure(figsize = (30,20))
data2 = df[df['weather_main']=='Snow']
sns.boxplot(x= data2['weather_description'], y= data2['traffic_volume'], data = data2)

# %% [markdown]
# ## we'll divide the snow in 3 categories
# heavy_snow consisting of columns snow, light snow
# moderate_snow consisting of heavy snow , light rain and snow
# light_snow consisting of sleet, light shower snow, shower snow

# %%
plt.figure(figsize = (20,15))
data3 = df[df['weather_main']=='Rain']
plt.subplot(2,1,1)
sns.boxplot(x= data3['weather_description'], y= data3['traffic_volume'], data = data3)
plt.subplot(2,1,2)
sns.boxplot(x= data3['weather_description'], y= data3['rain_1h'], data = data3)

# %% [markdown]
# # We'll divide / regroup the rain in 3 categories
# 1) Very heavy rain will be named as Heavy Rain
# 2) Light rain, moderate rain, heavy intensity rain will be named as Mooderate rain
# 3) Prox shower, freezing rain,light intensity shower rain will be named as Light rain due to high average of traffic flowing.

# %%
plt.figure(figsize = (20,15))
data4 = df[df['weather_main']=='Clear']
plt.subplot(2,1,1)
sns.boxplot(x= data4['weather_description'], y= data4['traffic_volume'], data = data4)

# %%
plt.figure(figsize = (20,30))
data5 = df[df['weather_main']=='Drizzle']
plt.subplot(2,1,1)
sns.boxplot(x= data5['weather_description'], y= data5['traffic_volume'], data = data5)

# %% [markdown]
# # We'll divide drizzle in 2 categories
# light intensity drizzle as light drizzle
# all others as heavy drizle

# %%
df[df['weather_main']=='Thunderstorm']['weather_description'].value_counts()
# Out:
# proximity thunderstorm                 673
# thunderstorm                           125
# thunderstorm with heavy rain            63
# thunderstorm with light rain            54
# proximity thunderstorm with rain        52
# thunderstorm with rain                  37
# thunderstorm with light drizzle         15
# proximity thunderstorm with drizzle     13
# thunderstorm with drizzle                2
# Name: weather_description, dtype: int64

# %%
plt.figure(figsize = (30,40))
data6 = df[df['weather_main']=='Thunderstorm']
plt.subplot(2,1,1)
sns.boxplot(x= data6['weather_description'], y= data6['traffic_volume'], data = data6)
plt.subplot(2,1,2)
sns.boxplot(x= data6['weather_description'], y= data6['rain_1h'], data = data6)

# %% [markdown]
# # Will divide thunderstorm 2 categories vbased on trafficvolume and the amount of rain
# strong_thunderstorm consisting of thunderstorm with light drizzle, thunderstorm with drizzle, thunderstorm with heavy rain
# light_thunderstrom of all others

# %%
plt.figure(figsize = (30,20))
data7 = df[df['weather_main']=='Drizzle']
plt.subplot(2,1,1)
sns.boxplot(x= data7['weather_description'], y= data7['traffic_volume'], data = data7)
plt.subplot(2,1,2)
sns.boxplot(x= data7['weather_description'], y= data7['rain_1h'], data = data7)

# %%
df['weather_description'].value_counts()
# Out:
# sky is clear                           11655
# mist                                    5950
# overcast clouds                         5081
# broken clouds                           4666
# scattered clouds                        3461
# light rain                              3372
# few clouds                              1956
# light snow                              1946
# Sky is Clear                            1726
# moderate rain                           1664
# haze                                    1360
# light intensity drizzle                 1100
# fog                                      912
# proximity thunderstorm                   673
# drizzle                                  651
# heavy snow                               616
# heavy intensity rain                     467
# snow                                     293
# proximity shower rain                    136
# thunderstorm                             125
# heavy intensity drizzle                   64
# ...

# %%
df['weather_main'].value_counts()
# Out:
# Clouds          15164
# Clear           13381
# Mist             5950
# Rain             5671
# Snow             2876
# Drizzle          1821
# Haze             1360
# Thunderstorm     1034
# Fog               912
# Smoke              20
# Squall              4
# Name: weather_main, dtype: int64

# %%
df[df['weather_main']== "Clouds"]["weather_description"].value_counts()
# Out:
# overcast clouds     5081
# broken clouds       4666
# scattered clouds    3461
# few clouds          1956
# Name: weather_description, dtype: int64

# %%
data1 = df[df["weather_main"] == "Clouds"]

# %%
plt.figure(figsize = (40,20))
sns.boxplot(x = df["weather_description"], y = df["traffic_volume"], data  = df)

# %%
plt.figure(figsize = (30,15))
sns.boxplot(x = data1["weather_description"], y = data1["traffic_volume"], data  = data1)

# %% [markdown]
# # we'll divide the clouds in 2 categories
# Overcast clous as high clouds
# all others as low clouds

# %%
plt.figure(figsize = (30,10))
sns.boxplot(x= data1['weather_description'], y= data1['clouds_all'], data = data1)

# %%
data1["weather_description"].value_counts()
# Out:
# overcast clouds     5081
# broken clouds       4666
# scattered clouds    3461
# few clouds          1956
# Name: weather_description, dtype: int64

# %%
plt.figure(figsize = (30,15))
plt.scatter(x = data1['temp'], y = data1["traffic_volume"])

# %%
df[:5]
# Out:
#   holiday    temp  ...           date_time  traffic_volume
# 0    None  288.28  ... 2012-10-02 09:00:00            5545
# 1    None  289.36  ... 2012-10-02 10:00:00            4516
# 2    None  289.58  ... 2012-10-02 11:00:00            4767
# 3    None  290.13  ... 2012-10-02 12:00:00            5026
# 4    None  291.14  ... 2012-10-02 13:00:00            4918
#
# [5 rows x 9 columns]

# %%
x1 = df['holiday'] != 'None'

# %%
plt.figure(figsize = (20,10))
sns.countplot(x = df[df['holiday'] != 'None']['holiday'], data =df)

# %%
plt.figure(figsize = (20,10))
sns.countplot(x = df['weather_main'], data =df)

# %%
plt.figure(figsize = (20,10))
sns.boxplot(x = df['weather_main'], y= df['traffic_volume'])

# %%
df['date_time'].describe()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   """Entry point for launching an IPython kernel.
# count                   48193
# unique                  40564
# top       2013-04-18 22:00:00
# freq                        6
# first     2012-10-02 09:00:00
# last      2018-09-30 23:00:00
# Name: date_time, dtype: object

# %%
df.dtypes
# Out:
# holiday                        object
# temp                          float64
# rain_1h                       float64
# snow_1h                       float64
# clouds_all                      int64
# weather_main                   object
# weather_description            object
# date_time              datetime64[ns]
# traffic_volume                  int64
# dtype: object

# %%
df['date_time'][:5]
# Out:
# 0   2012-10-02 09:00:00
# 1   2012-10-02 10:00:00
# 2   2012-10-02 11:00:00
# 3   2012-10-02 12:00:00
# 4   2012-10-02 13:00:00
# Name: date_time, dtype: datetime64[ns]

# %%
hour = df['date_time'].dt.hour
hour
# Out:
# 0         9
# 1        10
# 2        11
# 3        12
# 4        13
#          ..
# 48199    19
# 48200    20
# 48201    21
# 48202    22
# 48203    23
# Name: date_time, Length: 48193, dtype: int64

# %%
day = df['date_time'].dt.day
day
# Out:
# 0         2
# 1         2
# 2         2
# 3         2
# 4         2
#          ..
# 48199    30
# 48200    30
# 48201    30
# 48202    30
# 48203    30
# Name: date_time, Length: 48193, dtype: int64

# %%
df['date_time'].dt.month
# Out:
# 0        10
# 1        10
# 2        10
# 3        10
# 4        10
#          ..
# 48199     9
# 48200     9
# 48201     9
# 48202     9
# 48203     9
# Name: date_time, Length: 48193, dtype: int64

# %%
df['date_time'].dt.year
# Out:
# 0        2012
# 1        2012
# 2        2012
# 3        2012
# 4        2012
#          ...
# 48199    2018
# 48200    2018
# 48201    2018
# 48202    2018
# 48203    2018
# Name: date_time, Length: 48193, dtype: int64

# %%
df['date_time'].dt.weekday.value_counts()
# Out:
# 0    7071
# 2    6930
# 6    6866
# 1    6846
# 4    6832
# 5    6831
# 3    6817
# Name: date_time, dtype: int64

# %%
df1 = df.copy()
df1
# Out:
#       holiday    temp  ...           date_time  traffic_volume
# 0        None  288.28  ... 2012-10-02 09:00:00            5545
# 1        None  289.36  ... 2012-10-02 10:00:00            4516
# 2        None  289.58  ... 2012-10-02 11:00:00            4767
# 3        None  290.13  ... 2012-10-02 12:00:00            5026
# 4        None  291.14  ... 2012-10-02 13:00:00            4918
# ...       ...     ...  ...                 ...             ...
# 48199    None  283.45  ... 2018-09-30 19:00:00            3543
# 48200    None  282.76  ... 2018-09-30 20:00:00            2781
# 48201    None  282.73  ... 2018-09-30 21:00:00            2159
# 48202    None  282.09  ... 2018-09-30 22:00:00            1450
# 48203    None  282.12  ... 2018-09-30 23:00:00             954
#
# [48193 rows x 9 columns]

# %%
df1['hour'] = df['date_time'].dt.hour
df1['day'] = df['date_time'].dt.day
df1['month'] = df['date_time'].dt.month
df1['year'] = df['date_time'].dt.year
df1['weekday'] = df['date_time'].dt.weekday

# %%
df1
# Out:
#       holiday    temp  rain_1h  snow_1h  ...  day month  year weekday
# 0        None  288.28      0.0      0.0  ...    2    10  2012       1
# 1        None  289.36      0.0      0.0  ...    2    10  2012       1
# 2        None  289.58      0.0      0.0  ...    2    10  2012       1
# 3        None  290.13      0.0      0.0  ...    2    10  2012       1
# 4        None  291.14      0.0      0.0  ...    2    10  2012       1
# ...       ...     ...      ...      ...  ...  ...   ...   ...     ...
# 48199    None  283.45      0.0      0.0  ...   30     9  2018       6
# 48200    None  282.76      0.0      0.0  ...   30     9  2018       6
# 48201    None  282.73      0.0      0.0  ...   30     9  2018       6
# 48202    None  282.09      0.0      0.0  ...   30     9  2018       6
# 48203    None  282.12      0.0      0.0  ...   30     9  2018       6
#
# [48193 rows x 14 columns]

# %%
plt.figure(figsize = (30,30))
plt.subplot(2,1,1)
plt.scatter(x = df1['hour'], y = df1["traffic_volume"])
plt.subplot(2,1,2)
sns.boxplot(x = df1['hour'], y = df1["traffic_volume"])

# %% [markdown]
# # We divide the day into 4 hours i,e 0-5, 6-11, 12-17, 18-23

# %%
plt.figure(figsize = (30,20))
sns.boxplot(x = df1['weekday'], y = df1["traffic_volume"])

# %% [markdown]
# #As we observe that there is lesser traffic in day5 and day6, therefore we divide it into 2 categories, weekdays and weekends

# %%
plt.figure(figsize = (30,30))
sns.boxplot(x = df1['month'], y = df1["traffic_volume"])

# %% [markdown]
# ## we'll divide this into 3 categories
#  high traffic months -  May, june, Aug, Oct</br>
#  Mild traffic months - march, april, sept</br>
#  Low traffic months - jan, feb , july , nov, dec

# %%
plt.figure(figsize = (30,30))
sns.boxplot(x = df1['year'], y = df1["traffic_volume"])

# %%
df
# Out:
#       holiday    temp  rain_1h  snow_1h  ...  day month  year weekday
# 0        None  288.28      0.0      0.0  ...    2    10  2012       1
# 1        None  289.36      0.0      0.0  ...    2    10  2012       1
# 2        None  289.58      0.0      0.0  ...    2    10  2012       1
# 3        None  290.13      0.0      0.0  ...    2    10  2012       1
# 4        None  291.14      0.0      0.0  ...    2    10  2012       1
# ...       ...     ...      ...      ...  ...  ...   ...   ...     ...
# 48199    None  283.45      0.0      0.0  ...   30     9  2018       6
# 48200    None  282.76      0.0      0.0  ...   30     9  2018       6
# 48201    None  282.73      0.0      0.0  ...   30     9  2018       6
# 48202    None  282.09      0.0      0.0  ...   30     9  2018       6
# 48203    None  282.12      0.0      0.0  ...   30     9  2018       6
#
# [48193 rows x 14 columns]

# %% [markdown]
# ## Feature Engineering

# %%
a = df.copy()
a
# Out:
#       holiday    temp  rain_1h  snow_1h  ...  day month  year weekday
# 0        None  288.28      0.0      0.0  ...    2    10  2012       1
# 1        None  289.36      0.0      0.0  ...    2    10  2012       1
# 2        None  289.58      0.0      0.0  ...    2    10  2012       1
# 3        None  290.13      0.0      0.0  ...    2    10  2012       1
# 4        None  291.14      0.0      0.0  ...    2    10  2012       1
# ...       ...     ...      ...      ...  ...  ...   ...   ...     ...
# 48199    None  283.45      0.0      0.0  ...   30     9  2018       6
# 48200    None  282.76      0.0      0.0  ...   30     9  2018       6
# 48201    None  282.73      0.0      0.0  ...   30     9  2018       6
# 48202    None  282.09      0.0      0.0  ...   30     9  2018       6
# 48203    None  282.12      0.0      0.0  ...   30     9  2018       6
#
# [48193 rows x 14 columns]

# %%
a['Non_holiday'] = a['holiday'].apply(lambda x: 1 if x == "None" else 0)

# %%
a
# Out:
#       holiday    temp  rain_1h  snow_1h  ...  month  year weekday Non_holiday
# 0        None  288.28      0.0      0.0  ...     10  2012       1           1
# 1        None  289.36      0.0      0.0  ...     10  2012       1           1
# 2        None  289.58      0.0      0.0  ...     10  2012       1           1
# 3        None  290.13      0.0      0.0  ...     10  2012       1           1
# 4        None  291.14      0.0      0.0  ...     10  2012       1           1
# ...       ...     ...      ...      ...  ...    ...   ...     ...         ...
# 48199    None  283.45      0.0      0.0  ...      9  2018       6           1
# 48200    None  282.76      0.0      0.0  ...      9  2018       6           1
# 48201    None  282.73      0.0      0.0  ...      9  2018       6           1
# 48202    None  282.09      0.0      0.0  ...      9  2018       6           1
# 48203    None  282.12      0.0      0.0  ...      9  2018       6           1
#
# [48193 rows x 15 columns]

# %%
a['Non_holiday'].value_counts()
# Out:
# 1    48132
# 0       61
# Name: Non_holiday, dtype: int64

# %% [markdown]
# # We'll divide / regroup the rain in 3 categories
#  1) Very heavy rain will be named as Heavy Rain<br>
#  2) Light rain, moderate rain, heavy intensity rain will be named as Mooderate rain<br>
#  3) Prox shower, freezing rain,light intensity shower rain will be named as Light rain due to high average of traffic flowing.

# %%
a[a['weather_main'] =="Rain"]['weather_description'].value_counts()
# Out:
# light rain                     3372
# moderate rain                  1664
# heavy intensity rain            467
# proximity shower rain           136
# very heavy rain                  17
# light intensity shower rain      13
# freezing rain                     2
# Name: weather_description, dtype: int64

# %%
a['heavy_rain'] = df['weather_description'].apply(lambda x : 1 if x == 'very heavy rain' else 0) 
a['moderate_rain'] = df['weather_description'].apply(lambda x : 1 if x == 'light rain' or x == 'moderate rain' or x == 'heavy intensity rain' else 0) 
a['light_rain'] = df['weather_description'].apply(lambda x : 1 if x == 'proximity shower rain' or x == 'light intensity shower rain' or x == 'freezing rain' else 0)

# %%
a
# Out:
#       holiday    temp  rain_1h  ...  heavy_rain  moderate_rain light_rain
# 0        None  288.28      0.0  ...           0              0          0
# 1        None  289.36      0.0  ...           0              0          0
# 2        None  289.58      0.0  ...           0              0          0
# 3        None  290.13      0.0  ...           0              0          0
# 4        None  291.14      0.0  ...           0              0          0
# ...       ...     ...      ...  ...         ...            ...        ...
# 48199    None  283.45      0.0  ...           0              0          0
# 48200    None  282.76      0.0  ...           0              0          0
# 48201    None  282.73      0.0  ...           0              0          0
# 48202    None  282.09      0.0  ...           0              0          0
# 48203    None  282.12      0.0  ...           0              0          0
#
# [48193 rows x 18 columns]

# %%
a['moderate_rain'].value_counts()
# Out:
# 0    42690
# 1     5503
# Name: moderate_rain, dtype: int64

# %%
a['heavy_rain'].value_counts()
# Out:
# 0    48176
# 1       17
# Name: heavy_rain, dtype: int64

# %%
a['light_rain'].value_counts()
# Out:
# 0    48042
# 1      151
# Name: light_rain, dtype: int64

# %%
a[a['weather_main'] == 'Clouds']['weather_description'].value_counts()
# Out:
# overcast clouds     5081
# broken clouds       4666
# scattered clouds    3461
# few clouds          1956
# Name: weather_description, dtype: int64

# %%
a['clouds_high'] = a['weather_description'].apply(lambda x:1 if x == 'overcast clouds' else 0)
a['clouds_low'] = a['weather_description'].apply(lambda x:1 if x == 'broken clouds' or x == 'scattered clouds' or x == 'few clouds' else 0)

# %%
a['clouds_high'].value_counts()
# Out:
# 0    43112
# 1     5081
# Name: clouds_high, dtype: int64

# %%
a['clouds_low'].value_counts()
# Out:
# 0    38110
# 1    10083
# Name: clouds_low, dtype: int64

# %%
a
# Out:
#       holiday    temp  rain_1h  ...  light_rain  clouds_high clouds_low
# 0        None  288.28      0.0  ...           0            0          1
# 1        None  289.36      0.0  ...           0            0          1
# 2        None  289.58      0.0  ...           0            1          0
# 3        None  290.13      0.0  ...           0            1          0
# 4        None  291.14      0.0  ...           0            0          1
# ...       ...     ...      ...  ...         ...          ...        ...
# 48199    None  283.45      0.0  ...           0            0          1
# 48200    None  282.76      0.0  ...           0            1          0
# 48201    None  282.73      0.0  ...           0            0          0
# 48202    None  282.09      0.0  ...           0            1          0
# 48203    None  282.12      0.0  ...           0            1          0
#
# [48193 rows x 20 columns]

# %%
a[a['weather_main'] == 'Snow']['weather_description'].value_counts()
# Out:
# light snow             1946
# heavy snow              616
# snow                    293
# light shower snow        11
# light rain and snow       6
# sleet                     3
# shower snow               1
# Name: weather_description, dtype: int64

# %%
# #we'll divide the snow in 3 categories
# heavy_snow consisting of columns snow, light snow
# moderate_snow consisting of heavy snow , light rain and snow 
# light_snow consisting of sleet, light shower snow, shower snow

# %%
a['heavy_snow'] = a['weather_description'].apply(lambda x:1 if x == 'snow' or x == 'light snow' else 0)
a['moderate_snow'] = a['weather_description'].apply(lambda x:1 if x == 'heavy snow' or x == 'light rain and snow' else 0)
a['light_snow'] = a['weather_description'].apply(lambda x:1 if x == 'light shower snow' or x == 'shower snow' or x == 'sleet' else 0)

# %%
a
# Out:
#       holiday    temp  rain_1h  ...  heavy_snow  moderate_snow light_snow
# 0        None  288.28      0.0  ...           0              0          0
# 1        None  289.36      0.0  ...           0              0          0
# 2        None  289.58      0.0  ...           0              0          0
# 3        None  290.13      0.0  ...           0              0          0
# 4        None  291.14      0.0  ...           0              0          0
# ...       ...     ...      ...  ...         ...            ...        ...
# 48199    None  283.45      0.0  ...           0              0          0
# 48200    None  282.76      0.0  ...           0              0          0
# 48201    None  282.73      0.0  ...           0              0          0
# 48202    None  282.09      0.0  ...           0              0          0
# 48203    None  282.12      0.0  ...           0              0          0
#
# [48193 rows x 23 columns]

# %%
a['moderate_snow'].value_counts()
# Out:
# 0    47571
# 1      622
# Name: moderate_snow, dtype: int64

# %%
a[a['weather_main'] == "Clear"]['weather_description'].value_counts()
# Out:
# sky is clear    11655
# Sky is Clear     1726
# Name: weather_description, dtype: int64

# %%
a['clear_sky'] = a['weather_description'].apply(lambda x : 1 if x =='sky is clear' or x=='Sky is Clear' else 0)

# %%
a['clear_sky'].value_counts()
# Out:
# 0    34812
# 1    13381
# Name: clear_sky, dtype: int64

# %%
a[a['weather_main'] == "Drizzle"]['weather_description'].value_counts()
# Out:
# light intensity drizzle    1100
# drizzle                     651
# heavy intensity drizzle      64
# shower drizzle                6
# Name: weather_description, dtype: int64

# %%
a['heavy_drizzle'] = a['weather_description'].apply(lambda x : 1 if x =='heavy intensity drizzle' or x=='shower drizzle' or x=='drizzle' else 0)
a['light_drizzle'] = a['weather_description'].apply(lambda x : 1 if x =='light intensity drizzle' else 0)

# %%
a['heavy_drizzle'].value_counts()
# Out:
# 0    47472
# 1      721
# Name: heavy_drizzle, dtype: int64

# %%
a['light_drizzle'].value_counts()
# Out:
# 0    47093
# 1     1100
# Name: light_drizzle, dtype: int64

# %%
a[a['weather_main'] == "Thunderstorm"]['weather_description'].value_counts()
# Out:
# proximity thunderstorm                 673
# thunderstorm                           125
# thunderstorm with heavy rain            63
# thunderstorm with light rain            54
# proximity thunderstorm with rain        52
# thunderstorm with rain                  37
# thunderstorm with light drizzle         15
# proximity thunderstorm with drizzle     13
# thunderstorm with drizzle                2
# Name: weather_description, dtype: int64

# %%
# 2 categories vbased on trafficvolume and the amount of rain
# strong_thunderstorm consisting of thunderstorm with light drizzle, thunderstorm with drizzle, thunderstorm with heavy rain
# light_thunderstrom of all others

# %%
a['strong_storm'] = a['weather_description'].apply(lambda x : 1 if x =='thunderstorm with rain' or x=='thunderstorm with light drizzle' or x=='thunderstorm with drizzle' else 0)
a['light_thunderstorm'] = a['weather_description'].apply(lambda x : 1 if x =='thunderstorm with heavy rain' or x=='thunderstorm with light rain' or x=='thunderstorm' or x=='proximity thunderstorm'or x=='proximity thunderstorm with rain' or x=='proximity thunderstorm with drizzle' else 0)

# %%
a
# Out:
#       holiday    temp  rain_1h  ...  light_drizzle  strong_storm light_thunderstorm
# 0        None  288.28      0.0  ...              0             0                  0
# 1        None  289.36      0.0  ...              0             0                  0
# 2        None  289.58      0.0  ...              0             0                  0
# 3        None  290.13      0.0  ...              0             0                  0
# 4        None  291.14      0.0  ...              0             0                  0
# ...       ...     ...      ...  ...            ...           ...                ...
# 48199    None  283.45      0.0  ...              0             0                  0
# 48200    None  282.76      0.0  ...              0             0                  0
# 48201    None  282.73      0.0  ...              0             0                  1
# 48202    None  282.09      0.0  ...              0             0                  0
# ...

# %%
a['strong_storm'].value_counts()
# Out:
# 0    48139
# 1       54
# Name: strong_storm, dtype: int64

# %%
a['light_thunderstorm'].value_counts()
# Out:
# 0    47213
# 1      980
# Name: light_thunderstorm, dtype: int64

# %%
a[a['weather_main'] == "Fog"]['weather_description'].value_counts()
# Out:
# fog    912
# Name: weather_description, dtype: int64

# %%
a[a['weather_main'] == "Mist"]['weather_description'].value_counts()
# Out:
# mist    5950
# Name: weather_description, dtype: int64

# %%
a['fog_mist'] = a['weather_description'].apply(lambda x : 1 if x =='fog'  or x =='mist'  else 0)

# %%
a.shape
# Out:
# (48193, 29)

# %%
plt.figure(figsize=(15,10))
sns.countplot(x = a['weather_main'], data =a)

# %%
a['weather_main'].value_counts()
# Out:
# Clouds          15164
# Clear           13381
# Mist             5950
# Rain             5671
# Snow             2876
# Drizzle          1821
# Haze             1360
# Thunderstorm     1034
# Fog               912
# Smoke              20
# Squall              4
# Name: weather_main, dtype: int64

# %%
a[a['weather_main'] == "Haze"]['weather_description'].value_counts()
# Out:
# haze    1360
# Name: weather_description, dtype: int64

# %%
a[a['weather_main'] == "Squall"]['weather_description'].value_counts()
# Out:
# SQUALLS    4
# Name: weather_description, dtype: int64

# %%
a[a['weather_main'] == "Smoke"]['weather_description'].value_counts()
# Out:
# smoke    20
# Name: weather_description, dtype: int64

# %%
#Well combine the cases haze, squall and smoke
a['smoke'] = a['weather_description'].apply(lambda x : 1 if x =='haze'  or x =='SQUALLS' or x =='smoke'  else 0)

# %%
a['smoke'].value_counts()
# Out:
# 0    46809
# 1     1384
# Name: smoke, dtype: int64

# %%
a
# Out:
#       holiday    temp  rain_1h  ...  light_thunderstorm  fog_mist smoke
# 0        None  288.28      0.0  ...                   0         0     0
# 1        None  289.36      0.0  ...                   0         0     0
# 2        None  289.58      0.0  ...                   0         0     0
# 3        None  290.13      0.0  ...                   0         0     0
# 4        None  291.14      0.0  ...                   0         0     0
# ...       ...     ...      ...  ...                 ...       ...   ...
# 48199    None  283.45      0.0  ...                   0         0     0
# 48200    None  282.76      0.0  ...                   0         0     0
# 48201    None  282.73      0.0  ...                   1         0     0
# 48202    None  282.09      0.0  ...                   0         0     0
# 48203    None  282.12      0.0  ...                   0         0     0
#
# [48193 rows x 30 columns]

# %%
# we'll divide this into 3 categories
# high traffic months -  May, june, Aug, Oct
# Mild traffic months - march, april, sept
# Low traffic months - jan, feb , july , nov, dec

# %%
a['month'].value_counts()
# Out:
# 7     4794
# 5     4436
# 8     4378
# 4     4259
# 12    4249
# 1     4002
# 9     3831
# 3     3793
# 6     3772
# 11    3686
# 2     3520
# 10    3473
# Name: month, dtype: int64

# %%
a['high_traffic_months'] = a['month'].apply(lambda x: 1 if x == 5 or x==6 or x==8 or x==10 else 0)
a['medium_traffic_months'] = a['month'].apply(lambda x: 1 if x == 3 or x==4 or x==9 else 0 )
a['low_traffic_months'] = a['month'].apply(lambda x: 1 if x == 1 or x==2 or x==7 or x==11 or x==12 else 0)

# %%
a
# Out:
#       holiday    temp  ...  medium_traffic_months  low_traffic_months
# 0        None  288.28  ...                      0                   0
# 1        None  289.36  ...                      0                   0
# 2        None  289.58  ...                      0                   0
# 3        None  290.13  ...                      0                   0
# 4        None  291.14  ...                      0                   0
# ...       ...     ...  ...                    ...                 ...
# 48199    None  283.45  ...                      1                   0
# 48200    None  282.76  ...                      1                   0
# 48201    None  282.73  ...                      1                   0
# 48202    None  282.09  ...                      1                   0
# 48203    None  282.12  ...                      1                   0
#
# [48193 rows x 33 columns]

# %%
# a.drop(['kow_traffic_months'], axis=1, inplace=True)

# %%
a
# Out:
#       holiday    temp  ...  medium_traffic_months  low_traffic_months
# 0        None  288.28  ...                      0                   0
# 1        None  289.36  ...                      0                   0
# 2        None  289.58  ...                      0                   0
# 3        None  290.13  ...                      0                   0
# 4        None  291.14  ...                      0                   0
# ...       ...     ...  ...                    ...                 ...
# 48199    None  283.45  ...                      1                   0
# 48200    None  282.76  ...                      1                   0
# 48201    None  282.73  ...                      1                   0
# 48202    None  282.09  ...                      1                   0
# 48203    None  282.12  ...                      1                   0
#
# [48193 rows x 33 columns]

# %%
a['weekday'].value_counts()
# Out:
# 0    7071
# 2    6930
# 6    6866
# 1    6846
# 4    6832
# 5    6831
# 3    6817
# Name: weekday, dtype: int64

# %%
# a['weekend'] = a['weekday'].apply(lambda x: 1 if x == 5 or x==6 else 0 )

# %%
#a.drop(['weekdays','weekend'], axis =1 , inplace =True)

a['weekend'] = a['weekday'].apply(lambda x: 1 if x == 5 or x==6 else 0 )

# %%
a['weekend'].value_counts()
# Out:
# 0    34496
# 1    13697
# Name: weekend, dtype: int64

# %%
# We divide the day into 4 hours i,e 0-5, 6-11, 12-17, 18-23

# %%
a['dawn'] = a['hour'].apply(lambda x: 1 if x == 0 or x ==1 or x==2 or x== 3 or x==4 or x==5 else 0)
a['morning'] = a['hour'].apply(lambda x: 1 if x == 6 or x ==7 or x==8 or x== 9 or x==10 or x==11 else 0)
a['afternoon'] = a['hour'].apply(lambda x: 1 if x == 12 or x ==13 or x==14 or x==15 or x==16 or x==17 else 0)
a['evening'] = a['hour'].apply(lambda x: 1 if x == 18 or x ==19 or x==2 or x== 21 or x==22 or x==23 else 0)

# %%
a
# Out:
#       holiday    temp  rain_1h  snow_1h  ...  dawn morning afternoon evening
# 0        None  288.28      0.0      0.0  ...     0       1         0       0
# 1        None  289.36      0.0      0.0  ...     0       1         0       0
# 2        None  289.58      0.0      0.0  ...     0       1         0       0
# 3        None  290.13      0.0      0.0  ...     0       0         1       0
# 4        None  291.14      0.0      0.0  ...     0       0         1       0
# ...       ...     ...      ...      ...  ...   ...     ...       ...     ...
# 48199    None  283.45      0.0      0.0  ...     0       0         0       1
# 48200    None  282.76      0.0      0.0  ...     0       0         0       0
# 48201    None  282.73      0.0      0.0  ...     0       0         0       1
# 48202    None  282.09      0.0      0.0  ...     0       0         0       1
# 48203    None  282.12      0.0      0.0  ...     0       0         0       1
#
# [48193 rows x 38 columns]

# %%
b = a.drop(['holiday', 'weather_main', 'weather_description', 'date_time', 'hour','day','weekday','month', 'year'], axis = 1)

# %%
b
# Out:
#          temp  rain_1h  snow_1h  clouds_all  ...  dawn  morning  afternoon  evening
# 0      288.28      0.0      0.0          40  ...     0        1          0        0
# 1      289.36      0.0      0.0          75  ...     0        1          0        0
# 2      289.58      0.0      0.0          90  ...     0        1          0        0
# 3      290.13      0.0      0.0          90  ...     0        0          1        0
# 4      291.14      0.0      0.0          75  ...     0        0          1        0
# ...       ...      ...      ...         ...  ...   ...      ...        ...      ...
# 48199  283.45      0.0      0.0          75  ...     0        0          0        1
# 48200  282.76      0.0      0.0          90  ...     0        0          0        0
# 48201  282.73      0.0      0.0          90  ...     0        0          0        1
# 48202  282.09      0.0      0.0          90  ...     0        0          0        1
# ...

# %%
b
# Out:
#          temp  rain_1h  snow_1h  clouds_all  ...  dawn  morning  afternoon  evening
# 0      288.28      0.0      0.0          40  ...     0        1          0        0
# 1      289.36      0.0      0.0          75  ...     0        1          0        0
# 2      289.58      0.0      0.0          90  ...     0        1          0        0
# 3      290.13      0.0      0.0          90  ...     0        0          1        0
# 4      291.14      0.0      0.0          75  ...     0        0          1        0
# ...       ...      ...      ...         ...  ...   ...      ...        ...      ...
# 48199  283.45      0.0      0.0          75  ...     0        0          0        1
# 48200  282.76      0.0      0.0          90  ...     0        0          0        0
# 48201  282.73      0.0      0.0          90  ...     0        0          0        1
# 48202  282.09      0.0      0.0          90  ...     0        0          0        1
# ...

# %%
b.columns.tolist()
# Out:
# ['temp',
#  'rain_1h',
#  'snow_1h',
#  'clouds_all',
#  'traffic_volume',
#  'Non_holiday',
#  'heavy_rain',
#  'moderate_rain',
#  'light_rain',
#  'clouds_high',
#  'clouds_low',
#  'heavy_snow',
#  'moderate_snow',
#  'light_snow',
#  'clear_sky',
#  'heavy_drizzle',
#  'light_drizzle',
#  'strong_storm',
#  'light_thunderstorm',
#  'fog_mist',
#  'smoke',
#  'high_traffic_months',
#  'medium_traffic_months',
#  'low_traffic_months',
#  'weekend',
#  'dawn',
#  'morning',
#  'afternoon',
#  'evening']

# %%
b.shape
# Out:
# (48193, 29)

# %%
y = b['traffic_volume']
X = b.drop(['traffic_volume'], axis = 1)

# %%
X.shape
# Out:
# (48193, 28)

# %%
y.shape
# Out:
# (48193,)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.3,random_state = 1)

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
m1 = LinearRegression()
m1.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred1 = m1.predict(X_test)

# %%
y_pred1[:10]
# Out:
# array([4787.36607487,  347.07285305, 3203.72581234, 1228.16272252,
#        5529.71285259, 4309.54518534, 4660.71742023, 3057.8011069 ,
#         858.70901977, 3163.68542087])

# %%
y_test[:10]
# Out:
# 37720    6233
# 22712     395
# 16619    2903
# 22637    2781
# 19027    5880
# 5345     4950
# 9473     5452
# 44504     969
# 45961     303
# 15175    3205
# Name: traffic_volume, dtype: int64

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
mse = mean_squared_error(y_test, y_pred1)
rmse = np.sqrt(mse)
rmse
# Out:
# 1002.7589482611179

# %%
r2 = r2_score(y_test, y_pred1)
r2
# Out:
# 0.7457259837822763

# %%
m1.score(X_test,y_test)
# Out:
# 0.7457259837822763

# %%
plt.figure(figsize = (20,10))
sns.scatterplot(y_test, y_pred1)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
sns.kdeplot(data = y_pred1)
plt.subplot(1,2,2)
sns.kdeplot(data= y_test)

# %%
cont  = df[['temp','rain_1h','snow_1h','clouds_all']]

# %%
cont
# Out:
#          temp  rain_1h  snow_1h  clouds_all
# 0      288.28      0.0      0.0          40
# 1      289.36      0.0      0.0          75
# 2      289.58      0.0      0.0          90
# 3      290.13      0.0      0.0          90
# 4      291.14      0.0      0.0          75
# ...       ...      ...      ...         ...
# 48199  283.45      0.0      0.0          75
# 48200  282.76      0.0      0.0          90
# 48201  282.73      0.0      0.0          90
# 48202  282.09      0.0      0.0          90
# 48203  282.12      0.0      0.0          90
#
# [48193 rows x 4 columns]

# %%
sns.heatmap(cont.corr(), annot=True)
plt.figure(figsize = (10,8))
plt.show()

# %% [markdown]
# ## Decission Tree

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
m2 = DecisionTreeRegressor()
m2.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')

# %%
y_pred2 = m2.predict(X_test)
y_pred2
# Out:
# array([5290.,  390., 2903., ..., 5346., 1112., 4266.])

# %%
r2_score(y_test, y_pred2)
# Out:
# 0.6932031976797088

# %%
m2.score(X_test, y_test)
# Out:
# 0.6932031976797088

# %%
print('R square score on train set and test set are :',m2.score(X_train,y_train),m2.score(X_test, y_test))
print('Root mean squared error :',np.sqrt(mean_squared_error(y_test,m2.predict(X_test))))
# Out:
# R square score on train set and test set are : 0.9918212232375535 0.6932031976797088
# Root mean squared error : 1101.4656785642042

# %%
for i in range(2,20):
    print('Depth is :',i)
    m2 = DecisionTreeRegressor(max_depth = i)
    m2.fit(X_train,y_train)
    print('R square score on train set and test set are :',m2.score(X_train,y_train),m2.score(X_test, y_test))
    print('Root mean squared error :',np.sqrt(mean_squared_error(y_test,m2.predict(X_test))))
# Out:
# Depth is : 2
# R square score on train set and test set are : 0.6466603388199663 0.6423516586946727
# Root mean squared error : 1189.2513755393168
# Depth is : 3
# R square score on train set and test set are : 0.7294888339924329 0.7283939492873532
# Root mean squared error : 1036.3710554194365
# Depth is : 4
# R square score on train set and test set are : 0.7661573668098989 0.7634056746445973
# Root mean squared error : 967.2699966959058
# Depth is : 5
# R square score on train set and test set are : 0.8047790809418482 0.7974458334611894
# Root mean squared error : 894.9858011330159
# Depth is : 6
# R square score on train set and test set are : 0.8095310143695054 0.8024994070849636
# Root mean squared error : 883.7506712722599
# Depth is : 7
# R square score on train set and test set are : 0.8133026471575608 0.8049082825960221
# Root mean squared error : 878.3446710037157
# Depth is : 8
# R square score on train set and test set are : 0.8173141350368602 0.8056657838950615
# ...

# %%
m3 = DecisionTreeRegressor(max_depth=8)
m3.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=8,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')

# %%
y_pred3 = m3.predict(X_test)

# %%
plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
sns.kdeplot(data = y_pred3)
plt.subplot(1,2,2)
sns.kdeplot(data= y_test)

# %%
plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
sns.kdeplot(data = y_pred2)
plt.subplot(1,2,2)
sns.kdeplot(data= y_test)

# %%
m2.feature_importances_
# Out:
# array([8.48304795e-02, 6.07354168e-03, 2.83186488e-04, 1.42491262e-02,
#        1.45526598e-05, 0.00000000e+00, 1.12039546e-03, 3.29083761e-04,
#        1.39662098e-03, 2.21061620e-03, 4.86823692e-04, 7.82525540e-04,
#        3.18526582e-05, 1.44233326e-03, 2.35734013e-04, 3.21644429e-04,
#        1.79213210e-04, 7.58449191e-04, 2.07525303e-03, 8.64036995e-04,
#        1.71279156e-03, 1.53711289e-03, 4.43788848e-03, 8.85258399e-02,
#        5.62643161e-01, 3.85227843e-02, 3.91532185e-02, 1.45781735e-01])

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
m4 = RandomForestRegressor()
m4.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
y_pred4 = m4.predict(X_test)
y_pred4
# Out:
# array([5552.05,  767.99, 2798.11, ..., 5373.31, 2299.76, 4660.41])

# %%
m4.score(X_train, y_train)
# Out:
# 0.9671361433320715

# %%
r2_score(y_test, y_pred4)
# Out:
# 0.7977786140070667

# %%
mse = mean_squared_error(y_test, y_pred4)
rmse = np.sqrt(mse)
rmse
# Out:
# 894.2503033189416

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    'max_depth': [2, 6, 10, 14, 18 ],
    'max_features': [2, 3, 4, 5],
    'n_estimators': [100, 200, 300, 400, 500 ]
}

# %%
grid_search = GridSearchCV(estimator = m4, param_grid = param_grid, 
                          cv = 3, n_jobs = -1, verbose = 2)

# %%
grid_search.fit(X_train , y_train)
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:   29.0s
# [Parallel(n_jobs=-1)]: Done 158 tasks      | elapsed:  3.9min
# /usr/local/lib/python3.6/dist-packages/joblib/externals/loky/process_executor.py:691: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# [Parallel(n_jobs=-1)]: Done 300 out of 300 | elapsed: 14.1min finished
# GridSearchCV(cv=3, error_score=nan,
#              estimator=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0,
#                                              criterion='mse', max_depth=None,
#                                              max_features='auto',
#                                              max_leaf_nodes=None,
# ...

# %%
grid_search.best_params_
# Out:
# {'max_depth': 14, 'max_features': 5, 'n_estimators': 300}

# %%
best_grid = grid_search.best_estimator_

# %%
y_pred5 = best_grid.predict(X_test)

# %%
y_pred5
# Out:
# array([5534.07165268,  788.79114612, 2859.04438314, ..., 5442.67504938,
#        2327.57928413, 4693.03503693])

# %%
best_grid.score(X_test, y_test)
# Out:
# 0.8155802292218121

# %%
r2_score(y_test, y_pred5)
# Out:
# 0.815580229221812

# %%
mse = mean_squared_error(y_test, y_pred5)
rmse = np.sqrt(mse)
rmse
# Out:
# 853.9831344041864

# %%
best_grid.score(X_train, y_train)
# Out:
# 0.8547633356401388

# %% [markdown]
# ## Ridge and Lasso Regression

# %%
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso

# %%
r1 = Ridge(alpha=0.01)
r1.fit(X_train, y_train)
# Out:
# Ridge(alpha=0.01, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
ypred_test_r1= r1.predict(X_test)
print(np.sqrt(mean_squared_error(y_test,ypred_test_r1))) 
print(r2_score(y_test, ypred_test_r1))
# Out:
# 1002.7577013516163
# 0.7457266161505841

# %%
ridge_params = {'alpha':[200, 230, 250,265, 270, 275, 290, 300, 500]}
grid_ridge = GridSearchCV(estimator = r1, param_grid=ridge_params).fit(X_train, y_train).best_estimator_

# %%
grid_ridge.score(X_train, y_train)
# Out:
# 0.749479900658223

# %%
grid_ridge.score(X_test, y_test)
# Out:
# 0.7453255948106998

# %%
y_pred_r = grid_ridge.predict(X_test)
mse = mean_squared_error(y_test, y_pred_r)
rmse  = np.sqrt(mse)
rmse
# Out:
# 1003.5481277902691

# %%
from sklearn.linear_model import Lasso
l1 = Lasso(alpha=0.01)
l1.fit(X_train, y_train)
# Out:
# Lasso(alpha=0.01, copy_X=True, fit_intercept=True, max_iter=1000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False)

# %%
y_pred_l1= l1.predict(X_test)
print(np.sqrt(mean_squared_error(y_test,y_pred_l1))) 
print(r2_score(y_test, y_pred_l1))
# Out:
# 1002.7484931645374
# 0.7457312860446855

# %%
lasso_params = {'alpha':[0.01, 0.015, 0.02, 0.025, 0.03]}
grid_lasso = GridSearchCV(estimator = l1, param_grid=lasso_params).fit(X_train, y_train).best_estimator_

# %%
grid_lasso.score(X_train, y_train)
# Out:
# 0.7501304049740538

# %%
grid_lasso.score(X_test, y_test)
# Out:
# 0.7457382893262348

# %% [markdown]
# ## XGBoost

# %%
import xgboost as xgb

# %%
# xg_reg = xgb.XGBRegressor(objective ='reg:linear', colsample_bytree = 0.3, learning_rate = 0.1,
#                 max_depth = 5, alpha = 10, n_estimators = 10)
# xg_reg.fit(X_train,y_train)

# %%
# y_pred_x1 = xg_reg.predict(X_test)
# rmse = np.sqrt(mean_squared_error(y_test, y_pred_x1))
# rmse

# %%
# xg_reg.score(X_train, y_train)

# %%
# xg_reg.score(X_test, y_test)

# %%
n_estimators = [100, 500, 900, 1100, 1500]
max_depth = [2, 3, 5, 10, 15]
booster=['gbtree','gblinear']
learning_rate=[0.05,0.1,0.15,0.20]
min_child_weight=[1,2,3,4]
base_score=[0.25,0.5,0.75,1]

# Define the grid of hyperparameters to search
hyperparameter_grid = {
    'n_estimators': n_estimators,
    'max_depth':max_depth,
    'learning_rate':learning_rate,
    'min_child_weight':min_child_weight,
    'booster':booster,
    'base_score':base_score
    }

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
xgb_model = xgb.XGBRegressor()
random_cv = RandomizedSearchCV(estimator=xgb_model,
            param_distributions=hyperparameter_grid,
            cv=5, n_iter=50,
            scoring = 'neg_mean_absolute_error',n_jobs = 4,
            verbose = 5, 
            return_train_score = True,
            random_state=42)
random_cv.fit(X_train, y_train)

# %%
random_cv.best_estimator_

# %%
xgb_model1 = xgb.XGBRegressor(base_score=0.25, booster='gbtree', colsample_bylevel=1,
             colsample_bynode=1, colsample_bytree=1, gamma=0,
             importance_type='gain', learning_rate=0.1, max_delta_step=0,
             max_depth=10, min_child_weight=3, missing=None, n_estimators=100,
             n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
             reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
             silent=None, subsample=1, verbosity=1)
xgb_model1.fit(X_train, y_train)

# %%
xgb_model1.score(X_train, y_train)

# %%
xgb_model1.score(X_test, y_test)

# %%
y_pred_xgb = xgb_model1.predict(X_test)
rms = np.sqrt(mean_squared_error(y_test, y_pred_xgb))
rms

# %% [markdown]
# ## LightGBM

# %%
import lightgbm as lgb

# %%
hyper_params = {
    'task': 'train',
    'boosting_type': 'gbdt',
    'objective': 'regression',
    'metric': ['rmse'],
    'learning_rate': 0.008,
    'feature_fraction': 0.8,
    'bagging_fraction': 0.7,
    'bagging_freq': 4,
    'verbose': 0,
    "max_depth": 20,
    "num_leaves": 256,  
    "max_bin": 512,
    "num_iterations": 1000,
    "n_estimators": 1200
}
gbm = lgb.LGBMRegressor(**hyper_params)

# %%
gbm.fit(X_train, y_train,
        eval_set=[(X_test, y_test)],
        eval_metric='rmse',
        early_stopping_rounds=500)
# Out:
# /usr/local/lib/python3.6/dist-packages/lightgbm/engine.py:118: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [1]	valid_0's rmse: 1975.73
# Training until validation scores don't improve for 500 rounds.
# [2]	valid_0's rmse: 1964.86
# [3]	valid_0's rmse: 1954.43
# [4]	valid_0's rmse: 1941.86
# [5]	valid_0's rmse: 1929.53
# [6]	valid_0's rmse: 1919
# [7]	valid_0's rmse: 1907.16
# [8]	valid_0's rmse: 1895.09
# [9]	valid_0's rmse: 1884.85
# [10]	valid_0's rmse: 1872.91
# [11]	valid_0's rmse: 1861.05
# [12]	valid_0's rmse: 1850.58
# [13]	valid_0's rmse: 1838.93
# [14]	valid_0's rmse: 1827.38
# [15]	valid_0's rmse: 1817.41
# [16]	valid_0's rmse: 1807.49
# [17]	valid_0's rmse: 1797.9
# [18]	valid_0's rmse: 1786.76
# [19]	valid_0's rmse: 1775.81
# [20]	valid_0's rmse: 1766.25
# [21]	valid_0's rmse: 1758.04
# [22]	valid_0's rmse: 1747.95
# [23]	valid_0's rmse: 1737.78
# ...

# %%
gbm.score(X_train, y_train)
# Out:
# 0.8605464137877052

# %%
gbm.score(X_test, y_test)
# Out:
# 0.8194727879643973

# %%
gbm.best_score_
# Out:
# defaultdict(dict, {'valid_0': {'rmse': 844.9225331161404}})

# %%
gbm.best_iteration_
# Out:
# 938

# %%
gbm.feature_importances_
# Out:
# array([112718,  13962,    178,  35333,     21,      0,   4478,    295,
#          4353,   5736,   2585,   1280,      0,   4386,   1108,   1684,
#            25,   1369,   4988,   2113,   8997,   7447,   6050,   5411,
#          2026,   2429,   2060,   3514])

# %%
plt.figure(figsize = (10,10))
sns.heatmap(cont.corr())

# %%
plt.figure(figsize = (20,10))
sns.heatmap(b.corr(), annot = True,fmt = ".1f")

# %%
c= b.drop(['light_rain', 'clouds_low', 'light_snow', 'light_drizzle', 'light_thunderstorm', 'low_traffic_months', 'evening'], axis=1)
c
# Out:
#          temp  rain_1h  snow_1h  clouds_all  ...  weekend  dawn  morning  afternoon
# 0      288.28      0.0      0.0          40  ...        0     0        1          0
# 1      289.36      0.0      0.0          75  ...        0     0        1          0
# 2      289.58      0.0      0.0          90  ...        0     0        1          0
# 3      290.13      0.0      0.0          90  ...        0     0        0          1
# 4      291.14      0.0      0.0          75  ...        0     0        0          1
# ...       ...      ...      ...         ...  ...      ...   ...      ...        ...
# 48199  283.45      0.0      0.0          75  ...        1     0        0          0
# 48200  282.76      0.0      0.0          90  ...        1     0        0          0
# 48201  282.73      0.0      0.0          90  ...        1     0        0          0
# 48202  282.09      0.0      0.0          90  ...        1     0        0          0
# ...

# %%
c = c.drop(['clear_sky'], axis = 1)

# %%
c
# Out:
#          temp  rain_1h  snow_1h  clouds_all  ...  weekend  dawn  morning  afternoon
# 0      288.28      0.0      0.0          40  ...        0     0        1          0
# 1      289.36      0.0      0.0          75  ...        0     0        1          0
# 2      289.58      0.0      0.0          90  ...        0     0        1          0
# 3      290.13      0.0      0.0          90  ...        0     0        0          1
# 4      291.14      0.0      0.0          75  ...        0     0        0          1
# ...       ...      ...      ...         ...  ...      ...   ...      ...        ...
# 48199  283.45      0.0      0.0          75  ...        1     0        0          0
# 48200  282.76      0.0      0.0          90  ...        1     0        0          0
# 48201  282.73      0.0      0.0          90  ...        1     0        0          0
# 48202  282.09      0.0      0.0          90  ...        1     0        0          0
# ...

# %%
yc= c['traffic_volume']
Xc = c.drop(['traffic_volume'], axis = 1)

# %%
Xc
# Out:
#          temp  rain_1h  snow_1h  clouds_all  ...  weekend  dawn  morning  afternoon
# 0      288.28      0.0      0.0          40  ...        0     0        1          0
# 1      289.36      0.0      0.0          75  ...        0     0        1          0
# 2      289.58      0.0      0.0          90  ...        0     0        1          0
# 3      290.13      0.0      0.0          90  ...        0     0        0          1
# 4      291.14      0.0      0.0          75  ...        0     0        0          1
# ...       ...      ...      ...         ...  ...      ...   ...      ...        ...
# 48199  283.45      0.0      0.0          75  ...        1     0        0          0
# 48200  282.76      0.0      0.0          90  ...        1     0        0          0
# 48201  282.73      0.0      0.0          90  ...        1     0        0          0
# 48202  282.09      0.0      0.0          90  ...        1     0        0          0
# ...

# %%
yc
# Out:
# 0        5545
# 1        4516
# 2        4767
# 3        5026
# 4        4918
#          ...
# 48199    3543
# 48200    2781
# 48201    2159
# 48202    1450
# 48203     954
# Name: traffic_volume, Length: 48193, dtype: int64

# %%
Xc_train,Xc_test,yc_train,yc_test = train_test_split(Xc,yc,test_size = 0.3,random_state = 1)

# %%
hyper_params = {
    'task': 'train',
    'boosting_type': 'gbdt',
    'objective': 'regression',
    'metric': ['rmse'],
    'learning_rate': 0.008,
    'feature_fraction': 0.8,
    'bagging_fraction': 0.7,
    'bagging_freq': 4,
    'verbose': 0,
    "max_depth": 20,
    "num_leaves": 256,  
    "max_bin": 512,
    "num_iterations": 1000,
    "n_estimators": 1200
}
c1 = lgb.LGBMRegressor(**hyper_params)

# %%
c1.fit(Xc_train, yc_train,
        eval_set=[(Xc_test, yc_test)],
        eval_metric='rmse',
        early_stopping_rounds=500)
# Out:
# /usr/local/lib/python3.6/dist-packages/lightgbm/engine.py:118: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [1]	valid_0's rmse: 1975.82
# Training until validation scores don't improve for 500 rounds.
# [2]	valid_0's rmse: 1963.27
# [3]	valid_0's rmse: 1953.15
# [4]	valid_0's rmse: 1943.64
# [5]	valid_0's rmse: 1934.61
# [6]	valid_0's rmse: 1922.38
# [7]	valid_0's rmse: 1910.16
# [8]	valid_0's rmse: 1904.93
# [9]	valid_0's rmse: 1895.26
# [10]	valid_0's rmse: 1886.02
# [11]	valid_0's rmse: 1880.5
# [12]	valid_0's rmse: 1875.05
# [13]	valid_0's rmse: 1865.93
# [14]	valid_0's rmse: 1856.1
# [15]	valid_0's rmse: 1844.59
# [16]	valid_0's rmse: 1834.84
# [17]	valid_0's rmse: 1824.81
# [18]	valid_0's rmse: 1815.22
# [19]	valid_0's rmse: 1804
# [20]	valid_0's rmse: 1792.88
# [21]	valid_0's rmse: 1781.97
# [22]	valid_0's rmse: 1772.8
# [23]	valid_0's rmse: 1763.58
# ...

# %%
c1.score(Xc_train, yc_train)
# Out:
# 0.8559000327683439

# %%
c1.score(Xc_test, yc_test)
# Out:
# 0.8156674423292696

# %%
c2 = DecisionTreeRegressor(max_depth=8)
c2.fit(Xc_train, yc_train)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=8,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')

# %%
c2.score(Xc_test, yc_test)
# Out:
# 0.8011266022444208

# %%
yc_pred = c2.predict(Xc_test)
rmse = np.sqrt(mean_squared_error(yc_test, yc_pred))
rmse
# Out:
# 886.8167791813995

# %%
a.groupby('weather_description').aggregate({'traffic_volume':[np.mean,np.size],
                                                              'clouds_all':'count','rain_1h':'mean','snow_1h':'mean'})
# Out:
#                                     traffic_volume         ...    rain_1h   snow_1h
#                                               mean   size  ...       mean      mean
# weather_description                                        ...
# SQUALLS                                2061.750000      4  ...   3.482500  0.000000
# Sky is Clear                           3423.148899   1726  ...   0.000000  0.000000
# broken clouds                          3661.142092   4666  ...   0.000000  0.000000
# drizzle                                3094.858679    651  ...   0.118710  0.000000
# few clouds                             3691.453476   1956  ...   0.000000  0.000000
# fog                                    2703.720395    912  ...   0.087007  0.000625
# freezing rain                          4314.000000      2  ...   0.000000  0.000000
# haze                                   3502.101471   1360  ...   0.046868  0.000000
# ...
